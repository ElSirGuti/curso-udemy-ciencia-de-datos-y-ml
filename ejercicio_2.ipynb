# %%
import pandas as pd

# %%
df = pd.read_csv('movies.csv')
df
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         10000 non-null  int64
#  1   Title        10000 non-null  object
#  2   Year         10000 non-null  int64
#  3   Score        10000 non-null  float64
#  4   Metascore    6781 non-null   float64
#  5   Genre        10000 non-null  object
#  6   Vote         10000 non-null  int64
#  7   Director     9999 non-null   object
#  8   Runtime      10000 non-null  int64
#  9   Revenue      7473 non-null   float64
#  10  Description  10000 non-null  object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 859.5+ KB

# %%
pd.set_option('display.max_columns', 4)
df
# Out:
#        Rank                     Title  ...  Revenue  \
# 0         1  The Shawshank Redemption  ...    28.34
# 1         2           The Dark Knight  ...   534.86
# 2         3                 Inception  ...   292.58
# 3         4                Fight Club  ...    37.03
# 4         5              Pulp Fiction  ...   107.93
# ...     ...                       ...  ...      ...
# 9995   9996     When Night Is Falling  ...     1.19
# 9996   9997                   Stachka  ...      NaN
# 9997   9998        November Criminals  ...      NaN
# 9998   9999                       120  ...      NaN
# 9999  10000                The Terror  ...      NaN
#
#                                             Description
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# ...

# %%
df.head(3)
# Out:
#    Rank                     Title  ...  Revenue  \
# 0     1  The Shawshank Redemption  ...    28.34
# 1     2           The Dark Knight  ...   534.86
# 2     3                 Inception  ...   292.58
#
#                                          Description
# 0  Two imprisoned men bond over a number of years...
# 1  When the menace known as the Joker emerges fro...
# 2  A thief who steals corporate secrets through t...
#
# [3 rows x 11 columns]

# %%
df.tail(3)
# Out:
#        Rank               Title  ...  Revenue  \
# 9997   9998  November Criminals  ...      NaN
# 9998   9999                 120  ...      NaN
# 9999  10000          The Terror  ...      NaN
#
#                                             Description
# 9997  After his friend is murdered, a Washington, D....
# 9998  During the Sarikamis Battle, the Ottoman army ...
# 9999  A young officer in Napoleon's Army pursues a m...
#
# [3 rows x 11 columns]

# %%
df['Score']
# Out:
# 0       9.3
# 1       9.0
# 2       8.8
# 3       8.8
# 4       8.9
#        ...
# 9995    6.6
# 9996    7.6
# 9997    5.3
# 9998    7.3
# 9999    5.0
# Name: Score, Length: 10000, dtype: float64

# %%
df.Score
# Out:
# 0       9.3
# 1       9.0
# 2       8.8
# 3       8.8
# 4       8.9
#        ...
# 9995    6.6
# 9996    7.6
# 9997    5.3
# 9998    7.3
# 9999    5.0
# Name: Score, Length: 10000, dtype: float64

# %%
df[['Score', 'Metascore']]
# Out:
#       Score  Metascore
# 0       9.3       80.0
# 1       9.0       84.0
# 2       8.8       74.0
# 3       8.8       66.0
# 4       8.9       94.0
# ...     ...        ...
# 9995    6.6        NaN
# 9996    7.6        NaN
# 9997    5.3       31.0
# 9998    7.3        NaN
# 9999    5.0        NaN
#
# [10000 rows x 2 columns]

# %%
df[['Score', 'Metascore', 'Vote']]
# Out:
#       Score  Metascore     Vote
# 0       9.3       80.0  2011509
# 1       9.0       84.0  1980200
# 2       8.8       74.0  1760209
# 3       8.8       66.0  1609459
# 4       8.9       94.0  1570194
# ...     ...        ...      ...
# 9995    6.6        NaN     6022
# 9996    7.6        NaN     6021
# 9997    5.3       31.0     6020
# 9998    7.3        NaN     6018
# 9999    5.0        NaN     6015
#
# [10000 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Year', 'Score', 'Metascore', 'Genre', 'Vote',
#        'Director', 'Runtime', 'Revenue', 'Description'],
#       dtype='object')

# %%
df.loc[0]
# Out:
# Rank                                                           1
# Title                                   The Shawshank Redemption
# Year                                                        1994
# Score                                                        9.3
# Metascore                                                   80.0
# Genre                                                      Drama
# Vote                                                     2011509
# Director                                          Frank Darabont
# Runtime                                                      142
# Revenue                                                    28.34
# Description    Two imprisoned men bond over a number of years...
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#    Rank                     Title  ...  Revenue  \
# 0     1  The Shawshank Redemption  ...    28.34
# 1     2           The Dark Knight  ...   534.86
#
#                                          Description
# 0  Two imprisoned men bond over a number of years...
# 1  When the menace known as the Joker emerges fro...
#
# [2 rows x 11 columns]

# %%
df.loc[[0,1,2],'Genre']
# Out:
# 0                        Drama
# 1         Action, Crime, Drama
# 2    Action, Adventure, Sci-Fi
# Name: Genre, dtype: object

# %%
df.iloc[[0,1,2],5]
# Out:
# 0                        Drama
# 1         Action, Crime, Drama
# 2    Action, Adventure, Sci-Fi
# Name: Genre, dtype: object

# %%
df.loc[[0,1], ['Year', 'Title']]
# Out:
#    Year                     Title
# 0  1994  The Shawshank Redemption
# 1  2008           The Dark Knight

# %%
df.Score.value_counts()
# Out:
# Score
# 7.2    431
# 7.3    422
# 7.1    391
# 6.8    387
# 6.6    386
#       ...
# 9.3      1
# 1.6      1
# 1.5      1
# 1.7      1
# 9.6      1
# Name: count, Length: 82, dtype: int64

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Comedy, Drama, Romance     494
# Drama                      482
# Comedy, Drama              407
# Drama, Romance             365
# Comedy                     357
#                           ...
# Action, Family               1
# Action, Comedy, Mystery      1
# Thriller, Drama              1
# Action, Sci-Fi, War          1
# Drama, Mystery, Music        1
# Name: count, Length: 486, dtype: int64

# %%
df['Director'].value_counts()
# Out:
# Director
# Woody Allen              48
# Alfred Hitchcock         38
# Clint Eastwood           35
# Steven Spielberg         31
# Ridley Scott             25
#                          ..
# Arnaud Desplechin         1
# Joe Miale                 1
# Semih Kaplanoglu          1
# Ben Sombogaart            1
# Hans-Christian Schmid     1
# Name: count, Length: 3907, dtype: int64

# %%
df.loc[[0,5,10], 'Director']
# Out:
# 0        Frank Darabont
# 5       Robert Zemeckis
# 10    Christopher Nolan
# Name: Director, dtype: object

# %%
df.loc[0:10, ['Director', 'Revenue']]
# Out:
#                 Director  Revenue
# 0         Frank Darabont    28.34
# 1      Christopher Nolan   534.86
# 2      Christopher Nolan   292.58
# 3          David Fincher    37.03
# 4      Quentin Tarantino   107.93
# 5        Robert Zemeckis   330.25
# 6          Peter Jackson   315.54
# 7         Lana Wachowski   171.48
# 8          Peter Jackson   377.85
# 9   Francis Ford Coppola   134.97
# 10     Christopher Nolan   448.14

# %%
df.set_index('Runtime')
# Out:
#           Rank                     Title  ...  Revenue  \
# Runtime                                   ...
# 142          1  The Shawshank Redemption  ...    28.34
# 152          2           The Dark Knight  ...   534.86
# 148          3                 Inception  ...   292.58
# 139          4                Fight Club  ...    37.03
# 154          5              Pulp Fiction  ...   107.93
# ...        ...                       ...  ...      ...
# 94        9996     When Night Is Falling  ...     1.19
# 95        9997                   Stachka  ...      NaN
# 85        9998        November Criminals  ...      NaN
# 114       9999                       120  ...      NaN
# 81       10000                The Terror  ...      NaN
#
#                                                Description
# Runtime
# 142      Two imprisoned men bond over a number of years...
# 152      When the menace known as the Joker emerges fro...
# 148      A thief who steals corporate secrets through t...
# ...

# %%
df.index
# Out:
# Index([142, 152, 148, 139, 154, 142, 178, 136, 201, 175,
#        ...
#        103,  90, 125, 105,  94,  94,  95,  85, 114,  81],
#       dtype='int64', name='Runtime', length=10000)

# %%
df.set_index('Runtime', inplace=True)
df.index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4244\2069326097.py in ?()
# ----> 1 df.set_index('Runtime', inplace=True)
#       2 df.index
#
# ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['Runtime'] are in the columns"

# %%
df
# Out:
#           Rank                     Title  ...  Revenue  \
# Runtime                                   ...
# 142          1  The Shawshank Redemption  ...    28.34
# 152          2           The Dark Knight  ...   534.86
# 148          3                 Inception  ...   292.58
# 139          4                Fight Club  ...    37.03
# 154          5              Pulp Fiction  ...   107.93
# ...        ...                       ...  ...      ...
# 94        9996     When Night Is Falling  ...     1.19
# 95        9997                   Stachka  ...      NaN
# 85        9998        November Criminals  ...      NaN
# 114       9999                       120  ...      NaN
# 81       10000                The Terror  ...      NaN
#
#                                                Description
# Runtime
# 142      Two imprisoned men bond over a number of years...
# 152      When the menace known as the Joker emerges fro...
# 148      A thief who steals corporate secrets through t...
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#       Runtime   Rank  ... Revenue  \
# 0         142      1  ...   28.34
# 1         152      2  ...  534.86
# 2         148      3  ...  292.58
# 3         139      4  ...   37.03
# 4         154      5  ...  107.93
# ...       ...    ...  ...     ...
# 9995       94   9996  ...    1.19
# 9996       95   9997  ...     NaN
# 9997       85   9998  ...     NaN
# 9998      114   9999  ...     NaN
# 9999       81  10000  ...     NaN
#
#                                             Description
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# ...                                                 ...
# 9995  An uptight and conservative woman, working on ...
# 9996  A group of oppressed factory workers go on str...
# ...

# %%
df = pd.read_csv('movies.csv', index_col = 'Vote')
df
# Out:
#           Rank                     Title  ...  Revenue  \
# Vote                                      ...
# 2011509      1  The Shawshank Redemption  ...    28.34
# 1980200      2           The Dark Knight  ...   534.86
# 1760209      3                 Inception  ...   292.58
# 1609459      4                Fight Club  ...    37.03
# 1570194      5              Pulp Fiction  ...   107.93
# ...        ...                       ...  ...      ...
# 6022      9996     When Night Is Falling  ...     1.19
# 6021      9997                   Stachka  ...      NaN
# 6020      9998        November Criminals  ...      NaN
# 6018      9999                       120  ...      NaN
# 6015     10000                The Terror  ...      NaN
#
#                                                Description
# Vote
# 2011509  Two imprisoned men bond over a number of years...
# 1980200  When the menace known as the Joker emerges fro...
# 1760209  A thief who steals corporate secrets through t...
# ...

# %%
df.loc[1980200]
# Out:
# Rank                                                           2
# Title                                            The Dark Knight
# Year                                                        2008
# Score                                                        9.0
# Metascore                                                   84.0
# Genre                                       Action, Crime, Drama
# Director                                       Christopher Nolan
# Runtime                                                      152
# Revenue                                                   534.86
# Description    When the menace known as the Joker emerges fro...
# Name: 1980200, dtype: object

# %%
df = pd.read_csv('movies.csv')
df
# Out:
#        Rank                     Title  ...  Revenue  \
# 0         1  The Shawshank Redemption  ...    28.34
# 1         2           The Dark Knight  ...   534.86
# 2         3                 Inception  ...   292.58
# 3         4                Fight Club  ...    37.03
# 4         5              Pulp Fiction  ...   107.93
# ...     ...                       ...  ...      ...
# 9995   9996     When Night Is Falling  ...     1.19
# 9996   9997                   Stachka  ...      NaN
# 9997   9998        November Criminals  ...      NaN
# 9998   9999                       120  ...      NaN
# 9999  10000                The Terror  ...      NaN
#
#                                             Description
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# ...

# %%
df['Director'] == 'Christopher Nolan'
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Director, Length: 10000, dtype: bool

# %%
filtro = df['Director'] == 'Christopher Nolan'

# %%
df[filtro]
# Out:
#       Rank                  Title  ...  Revenue  \
# 1        2        The Dark Knight  ...   534.86
# 2        3              Inception  ...   292.58
# 10      11  The Dark Knight Rises  ...   448.14
# 13      14           Interstellar  ...   188.02
# 16      17          Batman Begins  ...   206.85
# 24      25           The Prestige  ...    53.09
# 27      28                Memento  ...    25.54
# 229    230                Dunkirk  ...   188.37
# 551    552               Insomnia  ...    67.36
# 2102  2103              Following  ...     0.05
#
#                                             Description
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 10    Eight years after the Joker's reign of anarchy...
# 13    A team of explorers travel through a wormhole ...
# 16    After training with his mentor, Batman begins ...
# 24    After a tragic accident, two stage magicians e...
# ...

# %%
df.loc[filtro]
# Out:
#       Rank                  Title  ...  Revenue  \
# 1        2        The Dark Knight  ...   534.86
# 2        3              Inception  ...   292.58
# 10      11  The Dark Knight Rises  ...   448.14
# 13      14           Interstellar  ...   188.02
# 16      17          Batman Begins  ...   206.85
# 24      25           The Prestige  ...    53.09
# 27      28                Memento  ...    25.54
# 229    230                Dunkirk  ...   188.37
# 551    552               Insomnia  ...    67.36
# 2102  2103              Following  ...     0.05
#
#                                             Description
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 10    Eight years after the Joker's reign of anarchy...
# 13    A team of explorers travel through a wormhole ...
# 16    After training with his mentor, Batman begins ...
# 24    After a tragic accident, two stage magicians e...
# ...

# %%
df.loc[filtro, 'Title']
# Out:
# 1             The Dark Knight
# 2                   Inception
# 10      The Dark Knight Rises
# 13               Interstellar
# 16              Batman Begins
# 24               The Prestige
# 27                    Memento
# 229                   Dunkirk
# 551                  Insomnia
# 2102                Following
# Name: Title, dtype: object

# %%
filtro1 = (df['Director'] == 'Christopher Nolan') & (df['Score'] >= 8.5)
df[filtro1]
# Out:
#     Rank            Title  ...  Revenue  \
# 1      2  The Dark Knight  ...   534.86
# 2      3        Inception  ...   292.58
# 13    14     Interstellar  ...   188.02
# 24    25     The Prestige  ...    53.09
# 27    28          Memento  ...    25.54
#
#                                           Description
# 1   When the menace known as the Joker emerges fro...
# 2   A thief who steals corporate secrets through t...
# 13  A team of explorers travel through a wormhole ...
# 24  After a tragic accident, two stage magicians e...
# 27  A man with short-term memory loss attempts to ...
#
# [5 rows x 11 columns]

# %%
df.loc[filtro1, 'Title']
# Out:
# 1     The Dark Knight
# 2           Inception
# 13       Interstellar
# 24       The Prestige
# 27            Memento
# Name: Title, dtype: object

# %%
filtro2 = (df['Director'] == 'Christopher Nolan') | (df['Score'] >= 8.5)
df.loc[filtro2]
# Out:
#       Rank                     Title  ...  Revenue  \
# 0        1  The Shawshank Redemption  ...    28.34
# 1        2           The Dark Knight  ...   534.86
# 2        3                 Inception  ...   292.58
# 3        4                Fight Club  ...    37.03
# 4        5              Pulp Fiction  ...   107.93
# ...    ...                       ...  ...      ...
# 9161  9162                     Aruvi  ...      NaN
# 9294  9295            Canim Kardesim  ...      NaN
# 9603  9604             Aloko Udapadi  ...      NaN
# 9629  9630                Graves End  ...      NaN
# 9974  9975                     Zübük  ...      NaN
#
#                                             Description
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# ...

# %%
df[filtro1]
# Out:
#     Rank            Title  ...  Revenue  \
# 1      2  The Dark Knight  ...   534.86
# 2      3        Inception  ...   292.58
# 13    14     Interstellar  ...   188.02
# 24    25     The Prestige  ...    53.09
# 27    28          Memento  ...    25.54
#
#                                           Description
# 1   When the menace known as the Joker emerges fro...
# 2   A thief who steals corporate secrets through t...
# 13  A team of explorers travel through a wormhole ...
# 24  After a tragic accident, two stage magicians e...
# 27  A man with short-term memory loss attempts to ...
#
# [5 rows x 11 columns]

# %%
df.loc[-filtro1]
# Out:
#        Rank                                              Title  ...  Revenue  \
# 0         1                           The Shawshank Redemption  ...    28.34
# 3         4                                         Fight Club  ...    37.03
# 4         5                                       Pulp Fiction  ...   107.93
# 5         6                                       Forrest Gump  ...   330.25
# 6         7  The Lord of the Rings: The Fellowship of the Ring  ...   315.54
# ...     ...                                                ...  ...      ...
# 9995   9996                              When Night Is Falling  ...     1.19
# 9996   9997                                            Stachka  ...      NaN
# 9997   9998                                 November Criminals  ...      NaN
# 9998   9999                                                120  ...      NaN
# 9999  10000                                         The Terror  ...      NaN
#
# ...

# %%
high_score = df['Score']>=9.3
df.loc[high_score]
# Out:
#       Rank                     Title  ...  Revenue  \
# 0        1  The Shawshank Redemption  ...    28.34
# 1645  1646                    Dag II  ...      NaN
# 3914  3915            Hababam Sinifi  ...      NaN
# 5482  5483                  Aynabaji  ...      NaN
# 5979  5980                    Wheels  ...      NaN
# 9603  9604             Aloko Udapadi  ...      NaN
#
#                                             Description
# 0     Two imprisoned men bond over a number of years...
# 1645  In a desolate war zone where screams of the in...
# 3914  Lazy, uneducated students share a very close b...
# 5482  Ayna is an actor and the prison is his stage. ...
# 5979  Two suicidal paraplegic junkies hustle their w...
# 9603  Aloko Udapadi (Light Arose) is an Epic Film of...
#
# [6 rows x 11 columns]

# %%
df.loc[high_score, ['Title', 'Revenue']]
# Out:
#                          Title  Revenue
# 0     The Shawshank Redemption    28.34
# 1645                    Dag II      NaN
# 3914            Hababam Sinifi      NaN
# 5482                  Aynabaji      NaN
# 5979                    Wheels      NaN
# 9603             Aloko Udapadi      NaN

# %%
df['Genre']
# Out:
# 0                           Drama
# 1            Action, Crime, Drama
# 2       Action, Adventure, Sci-Fi
# 3                           Drama
# 4                    Crime, Drama
#                   ...
# 9995               Drama, Romance
# 9996                        Drama
# 9997        Crime, Drama, Mystery
# 9998          Drama, History, War
# 9999             Horror, Thriller
# Name: Genre, Length: 10000, dtype: object

# %%
genero = ['Drama']
filtro3 = df['Genre'].isin(genero)
df.loc[filtro3, 'Genre']
# Out:
# 0       Drama
# 3       Drama
# 31      Drama
# 52      Drama
# 79      Drama
#         ...
# 9961    Drama
# 9963    Drama
# 9965    Drama
# 9990    Drama
# 9996    Drama
# Name: Genre, Length: 482, dtype: object

# %%
filtro4 = df['Genre'].str.contains('Drama')
df.loc[filtro4, 'Genre']
# Out:
# 0                       Drama
# 1        Action, Crime, Drama
# 3                       Drama
# 4                Crime, Drama
# 5              Drama, Romance
#                 ...
# 9993            Comedy, Drama
# 9995           Drama, Romance
# 9996                    Drama
# 9997    Crime, Drama, Mystery
# 9998      Drama, History, War
# Name: Genre, Length: 5572, dtype: object

# %%
filtro3
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Genre, Length: 10000, dtype: bool

# %%
filtro4
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997     True
# 9998     True
# 9999    False
# Name: Genre, Length: 10000, dtype: bool

# %%
df.columns
df = pd.read_csv('movies.csv')
df
# Out:
#        Rank                     Title  ...  Revenue  \
# 0         1  The Shawshank Redemption  ...    28.34
# 1         2           The Dark Knight  ...   534.86
# 2         3                 Inception  ...   292.58
# 3         4                Fight Club  ...    37.03
# 4         5              Pulp Fiction  ...   107.93
# ...     ...                       ...  ...      ...
# 9995   9996     When Night Is Falling  ...     1.19
# 9996   9997                   Stachka  ...      NaN
# 9997   9998        November Criminals  ...      NaN
# 9998   9999                       120  ...      NaN
# 9999  10000                The Terror  ...      NaN
#
#                                             Description
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# ...

# %%
df.columns = [x.upper() for x in df.columns]
df.columns
# Out:
# Index(['RANK', 'TITLE', 'YEAR', 'SCORE', 'METASCORE', 'GENRE', 'VOTE',
#        'DIRECTOR', 'RUNTIME', 'REVENUE', 'DESCRIPTION'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['RANK', 'English_Title', 'YEAR', 'Puntuación', 'METASCORE', 'GENRE',
#        'VOTE', 'DIRECTOR', 'RUNTIME', 'REVENUE', 'DESCRIPTION'],
#       dtype='object')

# %%
df.rename(columns = {'TITLE': 'English Title', 'SCORE': 'Puntuación'}, inplace=True)
df.columns
# Out:
# Index(['RANK', 'English Title', 'YEAR', 'Puntuación', 'METASCORE', 'GENRE',
#        'VOTE', 'DIRECTOR', 'RUNTIME', 'REVENUE', 'DESCRIPTION'],
#       dtype='object')

# %%
df.loc[0]
# Out:
# RANK                                                             1
# English_Title                             The Shawshank Redemption
# YEAR                                                          1994
# Puntuación                                                     9.3
# METASCORE                                                     80.0
# GENRE                                                        Drama
# VOTE                                                       2011509
# DIRECTOR                                            Frank Darabont
# RUNTIME                                                        142
# REVENUE                                                      28.34
# DESCRIPTION      Two imprisoned men bond over a number of years...
# Name: 0, dtype: object

# %%
df.loc[0, ['English_Title', 'Puntuación']]
# Out:
# English_Title    The Shawshank Redemption
# Puntuación                            9.3
# Name: 0, dtype: object

# %%
df.loc[0, ['English_Title', 'Puntuación']] = ['The Mandalorian', 9.5]
df.loc[0]
# Out:
# RANK                                                             1
# English_Title                                      The Mandalorian
# YEAR                                                          1994
# Puntuación                                                     9.5
# METASCORE                                                     80.0
# GENRE                                                        Drama
# VOTE                                                       2011509
# DIRECTOR                                            Frank Darabont
# RUNTIME                                                        142
# REVENUE                                                      28.34
# DESCRIPTION      Two imprisoned men bond over a number of years...
# Name: 0, dtype: object

# %%
df.loc[0, ['English_Title']] = 'Batman'
df.loc[0]
# Out:
# RANK                                                             1
# English_Title                                               Batman
# YEAR                                                          1994
# Puntuación                                                     9.5
# METASCORE                                                     80.0
# GENRE                                                        Drama
# VOTE                                                       2011509
# DIRECTOR                                            Frank Darabont
# RUNTIME                                                        142
# REVENUE                                                      28.34
# DESCRIPTION      Two imprisoned men bond over a number of years...
# Name: 0, dtype: object

# %%
filtro5 = (df['English_Title']) == 'Batman'
df.loc[filtro5, 'YEAR']
# Out:
# 0      1994
# 414    1989
# Name: YEAR, dtype: int64

# %%
df.loc[filtro5, 'YEAR'] = 2000
df.loc[filtro5, 'YEAR']
# Out:
# 0      2000
# 414    2000
# Name: YEAR, dtype: int64

# %%
df['English_Title'].apply(len)
# Out:
# 0        6
# 1       15
# 2        9
# 3       10
# 4       12
#         ..
# 9995    21
# 9996     7
# 9997    18
# 9998     3
# 9999    10
# Name: English_Title, Length: 10000, dtype: int64

# %%
def actualizarTitulo(titulo):
    return titulo.upper()

df['English_Title'].apply(actualizarTitulo)
# Out:
# 0                      BATMAN
# 1             THE DARK KNIGHT
# 2                   INCEPTION
# 3                  FIGHT CLUB
# 4                PULP FICTION
#                 ...
# 9995    WHEN NIGHT IS FALLING
# 9996                  STACHKA
# 9997       NOVEMBER CRIMINALS
# 9998                      120
# 9999               THE TERROR
# Name: English_Title, Length: 10000, dtype: object

# %%
df
# Out:
#        RANK          English_Title  ...  REVENUE  \
# 0         1                 Batman  ...    28.34
# 1         2        The Dark Knight  ...   534.86
# 2         3              Inception  ...   292.58
# 3         4             Fight Club  ...    37.03
# 4         5           Pulp Fiction  ...   107.93
# ...     ...                    ...  ...      ...
# 9995   9996  When Night Is Falling  ...     1.19
# 9996   9997                Stachka  ...      NaN
# 9997   9998     November Criminals  ...      NaN
# 9998   9999                    120  ...      NaN
# 9999  10000             The Terror  ...      NaN
#
#                                             DESCRIPTION
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# ...

# %%
df['English_Title'] = df ['English_Title'].apply(actualizarTitulo)
df
# Out:
#        RANK          English_Title  ...  REVENUE  \
# 0         1                 BATMAN  ...    28.34
# 1         2        THE DARK KNIGHT  ...   534.86
# 2         3              INCEPTION  ...   292.58
# 3         4             FIGHT CLUB  ...    37.03
# 4         5           PULP FICTION  ...   107.93
# ...     ...                    ...  ...      ...
# 9995   9996  WHEN NIGHT IS FALLING  ...     1.19
# 9996   9997                STACHKA  ...      NaN
# 9997   9998     NOVEMBER CRIMINALS  ...      NaN
# 9998   9999                    120  ...      NaN
# 9999  10000             THE TERROR  ...      NaN
#
#                                             DESCRIPTION
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# ...

# %%
df['English_Title'] = df['English_Title'].apply(lambda x: x.lower())
df
# Out:
#        RANK          English_Title  ...  REVENUE  \
# 0         1                 batman  ...    28.34
# 1         2        the dark knight  ...   534.86
# 2         3              inception  ...   292.58
# 3         4             fight club  ...    37.03
# 4         5           pulp fiction  ...   107.93
# ...     ...                    ...  ...      ...
# 9995   9996  when night is falling  ...     1.19
# 9996   9997                stachka  ...      NaN
# 9997   9998     november criminals  ...      NaN
# 9998   9999                    120  ...      NaN
# 9999  10000             the terror  ...      NaN
#
#                                             DESCRIPTION
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# ...

# %%
len(df['English_Title'])
# Out:
# 10000

# %%
df['YEAR'].replace({2000:1000})
# Out:
# 0       1000
# 1       2008
# 2       2010
# 3       1999
# 4       1994
#         ...
# 9995    1995
# 9996    1925
# 9997    2017
# 9998    2008
# 9999    1963
# Name: YEAR, Length: 10000, dtype: int64

# %%
df.rename(columns={'YEAR': 'AÑO'}, inplace=True)
df
# Out:
#        RANK          English_Title  ...  REVENUE  \
# 0         1                 batman  ...    28.34
# 1         2        the dark knight  ...   534.86
# 2         3              inception  ...   292.58
# 3         4             fight club  ...    37.03
# 4         5           pulp fiction  ...   107.93
# ...     ...                    ...  ...      ...
# 9995   9996  when night is falling  ...     1.19
# 9996   9997                stachka  ...      NaN
# 9997   9998     november criminals  ...      NaN
# 9998   9999                    120  ...      NaN
# 9999  10000             the terror  ...      NaN
#
#                                             DESCRIPTION
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# ...

# %%
df = pd.read_csv('movies.csv')
df.loc[0]
# Out:
# Rank                                                           1
# Title                                   The Shawshank Redemption
# Year                                                        1994
# Score                                                        9.3
# Metascore                                                   80.0
# Genre                                                      Drama
# Vote                                                     2011509
# Director                                          Frank Darabont
# Runtime                                                      142
# Revenue                                                    28.34
# Description    Two imprisoned men bond over a number of years...
# Name: 0, dtype: object

# %%
df['Title'] + ' ' + df['Director']
# Out:
# 0       The Shawshank Redemption Frank Darabont
# 1             The Dark Knight Christopher Nolan
# 2                   Inception Christopher Nolan
# 3                      Fight Club David Fincher
# 4                Pulp Fiction Quentin Tarantino
#                          ...
# 9995      When Night Is Falling Patricia Rozema
# 9996               Stachka Sergei M. Eisenstein
# 9997           November Criminals Sacha Gervasi
# 9998                             120 Özhan Eren
# 9999                    The Terror Roger Corman
# Length: 10000, dtype: object

# %%
(df['Score'] + (df['Metascore'] / 10)) /  2
# Out:
# 0       8.65
# 1       8.70
# 2       8.10
# 3       7.70
# 4       9.15
#         ...
# 9995     NaN
# 9996     NaN
# 9997    4.20
# 9998     NaN
# 9999     NaN
# Length: 10000, dtype: float64

# %%
df['TotalScore'] = (df['Score'] + (df['Metascore'] / 10)) /  2
df
# Out:
#        Rank                     Title  ...  \
# 0         1  The Shawshank Redemption  ...
# 1         2           The Dark Knight  ...
# 2         3                 Inception  ...
# 3         4                Fight Club  ...
# 4         5              Pulp Fiction  ...
# ...     ...                       ...  ...
# 9995   9996     When Night Is Falling  ...
# 9996   9997                   Stachka  ...
# 9997   9998        November Criminals  ...
# 9998   9999                       120  ...
# 9999  10000                The Terror  ...
#
#                                             Description  TotalScore
# 0     Two imprisoned men bond over a number of years...        8.65
# 1     When the menace known as the Joker emerges fro...        8.70
# 2     A thief who steals corporate secrets through t...        8.10
# 3     An insomniac office worker and a devil-may-car...        7.70
# 4     The lives of two mob hitmen, a boxer, a gangst...        9.15
# ...

# %%
df.drop(columns=['TotalScore'], inplace=True)
df
# Out:
#        Rank                     Title  ...  Revenue  \
# 0         1  The Shawshank Redemption  ...    28.34
# 1         2           The Dark Knight  ...   534.86
# 2         3                 Inception  ...   292.58
# 3         4                Fight Club  ...    37.03
# 4         5              Pulp Fiction  ...   107.93
# ...     ...                       ...  ...      ...
# 9995   9996     When Night Is Falling  ...     1.19
# 9996   9997                   Stachka  ...      NaN
# 9997   9998        November Criminals  ...      NaN
# 9998   9999                       120  ...      NaN
# 9999  10000                The Terror  ...      NaN
#
#                                             Description
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# ...

# %%
df.drop(index=1)
# Out:
#        Rank                     Title  ...  Revenue  \
# 0         1  The Shawshank Redemption  ...    28.34
# 2         3                 Inception  ...   292.58
# 3         4                Fight Club  ...    37.03
# 4         5              Pulp Fiction  ...   107.93
# 5         6              Forrest Gump  ...   330.25
# ...     ...                       ...  ...      ...
# 9995   9996     When Night Is Falling  ...     1.19
# 9996   9997                   Stachka  ...      NaN
# 9997   9998        November Criminals  ...      NaN
# 9998   9999                       120  ...      NaN
# 9999  10000                The Terror  ...      NaN
#
#                                             Description
# 0     Two imprisoned men bond over a number of years...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# ...

# %%
df.drop(index=df[df['Score']==9.3].index)
# Out:
#        Rank                  Title  ...  Revenue  \
# 1         2        The Dark Knight  ...   534.86
# 2         3              Inception  ...   292.58
# 3         4             Fight Club  ...    37.03
# 4         5           Pulp Fiction  ...   107.93
# 5         6           Forrest Gump  ...   330.25
# ...     ...                    ...  ...      ...
# 9995   9996  When Night Is Falling  ...     1.19
# 9996   9997                Stachka  ...      NaN
# 9997   9998     November Criminals  ...      NaN
# 9998   9999                    120  ...      NaN
# 9999  10000             The Terror  ...      NaN
#
#                                             Description
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# 5     The presidencies of Kennedy and Johnson, Vietn...
# ...

# %%
filtro6 = df['Score'] == 9.3
df.drop(index=df[filtro6].index)
# Out:
#        Rank                  Title  ...  Revenue  \
# 1         2        The Dark Knight  ...   534.86
# 2         3              Inception  ...   292.58
# 3         4             Fight Club  ...    37.03
# 4         5           Pulp Fiction  ...   107.93
# 5         6           Forrest Gump  ...   330.25
# ...     ...                    ...  ...      ...
# 9995   9996  When Night Is Falling  ...     1.19
# 9996   9997                Stachka  ...      NaN
# 9997   9998     November Criminals  ...      NaN
# 9998   9999                    120  ...      NaN
# 9999  10000             The Terror  ...      NaN
#
#                                             Description
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# 5     The presidencies of Kennedy and Johnson, Vietn...
# ...

# %%
df.sort_values(by='Score')
# Out:
#       Rank                           Title  ...  Revenue  \
# 3632  3633  Cumali Ceber: Allah Seni Alsin  ...      NaN
# 9852  9853                  Kartoffelsalat  ...      NaN
# 8972  8973                        Smolensk  ...      NaN
# 6340  6341                Saving Christmas  ...     2.78
# 4422  4423                  Kod Adi K.O.Z.  ...      NaN
# ...    ...                             ...  ...      ...
# 1645  1646                          Dag II  ...      NaN
# 3914  3915                  Hababam Sinifi  ...      NaN
# 5979  5980                          Wheels  ...      NaN
# 5482  5483                        Aynabaji  ...      NaN
# 9603  9604                   Aloko Udapadi  ...      NaN
#
#                                             Description
# 3632  Cumali Ceber goes to a vacation with his child...
# 9852  When a deadly zombie virus infects a school in...
# 8972  Inspired by true events of 2010 Polish Air For...
# ...

# %%
df.sort_values(by='Score', ascending=False)
# Out:
#       Rank                           Title  ...  Revenue  \
# 9603  9604                   Aloko Udapadi  ...      NaN
# 5482  5483                        Aynabaji  ...      NaN
# 1645  1646                          Dag II  ...      NaN
# 3914  3915                  Hababam Sinifi  ...      NaN
# 5979  5980                          Wheels  ...      NaN
# ...    ...                             ...  ...      ...
# 4422  4423                  Kod Adi K.O.Z.  ...      NaN
# 6340  6341                Saving Christmas  ...     2.78
# 8972  8973                        Smolensk  ...      NaN
# 3632  3633  Cumali Ceber: Allah Seni Alsin  ...      NaN
# 9852  9853                  Kartoffelsalat  ...      NaN
#
#                                             Description
# 9603  Aloko Udapadi (Light Arose) is an Epic Film of...
# 5482  Ayna is an actor and the prison is his stage. ...
# 1645  In a desolate war zone where screams of the in...
# ...

# %%
df.sort_index()
# Out:
#        Rank                     Title  ...  Revenue  \
# 0         1  The Shawshank Redemption  ...    28.34
# 1         2           The Dark Knight  ...   534.86
# 2         3                 Inception  ...   292.58
# 3         4                Fight Club  ...    37.03
# 4         5              Pulp Fiction  ...   107.93
# ...     ...                       ...  ...      ...
# 9995   9996     When Night Is Falling  ...     1.19
# 9996   9997                   Stachka  ...      NaN
# 9997   9998        November Criminals  ...      NaN
# 9998   9999                       120  ...      NaN
# 9999  10000                The Terror  ...      NaN
#
#                                             Description
# 0     Two imprisoned men bond over a number of years...
# 1     When the menace known as the Joker emerges fro...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# ...

# %%
df.sort_values(by='Title', inplace=True)
df
# Out:
#       Rank                               Title  ...  Revenue  \
# 3165  3166                                 '71  ...     1.27
# 6645  6646                         'A' gai wak  ...      NaN
# 8655  8656                       'A' gai wak 2  ...      NaN
# 9286  9287           'I Know Where I'm Going!'  ...      NaN
# 6794  6795  (T)Raumschiff Surprise - Periode 1  ...      NaN
# ...    ...                                 ...  ...      ...
# 7702  7703                         Çalgi Çengi  ...      NaN
# 8747  8748                         Çiçek Abbas  ...      NaN
# 5929  5930                      Çöpçüler Krali  ...      NaN
# 8529  8530                        Ölümlü Dünya  ...      NaN
# 5741  5742                           Üç Maymun  ...     0.04
#
#                                             Description
# 3165  In 1971, a young and disorientated British sol...
# 6645  Fighting against pirates in "old Hong Kong". C...
# 8655  Dragon is now transferred to be the police hea...
# ...

# %%
df[['Title', 'Score']].head(10)
# Out:
#                                      Title  Score
# 3165                                   '71    7.2
# 6645                           'A' gai wak    7.4
# 8655                         'A' gai wak 2    7.2
# 9286             'I Know Where I'm Going!'    7.6
# 6794    (T)Raumschiff Surprise - Periode 1    5.4
# 4349               *batteries not included    6.6
# 5579  ...E tu vivrai nel terrore! L'aldilà    6.9
# 4399               ...and justice for all.    7.4
# 8686                                  0.45    5.7
# 6144                                 02:22    5.7

# %%
df.sort_values(by='Genre', inplace = True)
df[['Title', 'Genre']]
# Out:
#                             Title    Genre
# 9008                   Himmatwala   Action
# 8344                      Redline   Action
# 6935                    Ong-bak 3   Action
# 7820                         Boss   Action
# 2648  The Man with the Iron Fists   Action
# ...                           ...      ...
# 779        For a Few Dollars More  Western
# 8363               One-Eyed Jacks  Western
# 7346        Ride the High Country  Western
# 911          A Fistful of Dollars  Western
# 6183                     Joe Kidd  Western
#
# [10000 rows x 2 columns]

# %%
df[['Score','Genre']].head(10)
# Out:
#       Score   Genre
# 9008    1.7  Action
# 8344    4.0  Action
# 6935    5.0  Action
# 7820    5.5  Action
# 2648    5.4  Action
# 9369    7.3  Action
# 9647    6.2  Action
# 5412    5.8  Action
# 4356    6.2  Action
# 7584    7.2  Action

# %%
df.sort_values(by=['Genre','Score'], ascending=[True, False], inplace = True)
df[['Title','Score','Genre']].head(10)
# Out:
#                             Title  Score   Genre
# 9369                         Ayan    7.3  Action
# 7584     Choi-jong-byeong-gi hwal    7.2  Action
# 9647                     Bairavaa    6.2  Action
# 4356                    Ong-bak 2    6.2  Action
# 5412                Rowdy Rathore    5.8  Action
# 7820                         Boss    5.5  Action
# 2648  The Man with the Iron Fists    5.4  Action
# 6935                    Ong-bak 3    5.0  Action
# 8344                      Redline    4.0  Action
# 9008                   Himmatwala    1.7  Action

# %%
df['Runtime'].nlargest(10)
# Out:
# 8862    450
# 5377    366
# 6957    325
# 2401    321
# 5220    317
# 4676    259
# 9771    242
# 3838    242
# 9905    240
# 530     238
# Name: Runtime, dtype: int64

# %%
df.nlargest(10,'Runtime')
# Out:
#       Rank                    Title  ...  Revenue  \
# 8862  8863               Sátántangó  ...      NaN
# 5377  5378       La meglio gioventù  ...     0.25
# 6957  6958            Heaven's Gate  ...     3.48
# 2401  2402       Gangs of Wasseypur  ...      NaN
# 5220  5221                Novecento  ...      NaN
# 4676  4677               Gettysburg  ...    10.77
# 9771  9772  Dr. Mabuse, der Spieler  ...      NaN
# 3838  3839                   Hamlet  ...     4.41
# 9905  9906                 Napoleon  ...      NaN
# 530    531       Gone with the Wind  ...   198.68
#
#                                             Description
# 8862  Plotting on a payment they are about to receiv...
# 5377  An Italian epic that follows the lives of two ...
# 6957  A dramatization of the real-life Johnson Count...
# 2401  A clash between Sultan and Shahid Khan leads t...
# 5220  The epic tale of a class struggle in twentieth...
# 4676  In 1863, the Northern and Southern forces figh...
# ...

# %%
df.nsmallest(10, 'Runtime')
# Out:
#       Rank                                              Title  ...  Revenue  \
# 4095  4096                                       Sherlock Jr.  ...     0.98
# 7977  7978                                 Hotarubi no mori e  ...      NaN
# 4839  4840                                 Koto no ha no niwa  ...      NaN
# 9149  9150                                The Call of Cthulhu  ...      NaN
# 7166  7167                            Blood: The Last Vampire  ...      NaN
# 8547  8548  Dragon Ball Z: Fukkatsu no Fusion!! Gokuu to V...  ...      NaN
# 9652  9653  Doragon bôru Z: Ryûken bakuhatsu!! Gokû ga yar...  ...      NaN
# 9207  9208                           The Beast of Yucca Flats  ...      NaN
# 8602  8603                                      Seven Chances  ...     0.21
# 8574  8575                                      The Navigator  ...     1.48
#
#                                             Description
# 4095  A film projectionist longs to be a detective, ...
# ...

# %%
df['Score'].mean()
# Out:
# np.float64(6.627529999999999)

# %%
df['Score'].describe()
# Out:
# count    10000.000000
# mean         6.627530
# std          1.041204
# min          1.300000
# 25%          6.000000
# 50%          6.700000
# 75%          7.400000
# max          9.600000
# Name: Score, dtype: float64

# %%
df['Score'].count()
# Out:
# np.int64(10000)

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Comedy, Drama, Romance       494
# Drama                        482
# Comedy, Drama                407
# Drama, Romance               365
# Comedy                       357
#                             ...
# Action, Biography, Comedy      1
# Action, Comedy, Adventure      1
# Action, Comedy, History        1
# Action, Comedy, Music          1
# Action, Comedy, Mystery        1
# Name: count, Length: 486, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 7.2    431
# 7.3    422
# 7.1    391
# 6.8    387
# 6.6    386
#       ...
# 1.5      1
# 9.2      1
# 1.6      1
# 9.3      1
# 9.6      1
# Name: count, Length: 82, dtype: int64

# %%
df['Score'].value_counts(normalize=True)
# Out:
# Score
# 7.2    0.0431
# 7.3    0.0422
# 7.1    0.0391
# 6.8    0.0387
# 6.6    0.0386
#         ...
# 1.5    0.0001
# 9.2    0.0001
# 1.6    0.0001
# 9.3    0.0001
# 9.6    0.0001
# Name: proportion, Length: 82, dtype: float64

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Comedy, Drama, Romance       494
# Drama                        482
# Comedy, Drama                407
# Drama, Romance               365
# Comedy                       357
#                             ...
# Action, Biography, Comedy      1
# Action, Comedy, Adventure      1
# Action, Comedy, History        1
# Action, Comedy, Music          1
# Action, Comedy, Mystery        1
# Name: count, Length: 486, dtype: int64

# %%
df.groupby(['Genre'])

# %%
genre_group = df.groupby(['Genre'])

# %%
genre_group.get_group('Drama')
# Out:
# C:\Users\a.gutierrez\AppData\Local\Temp\ipykernel_4244\1811228754.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   genre_group.get_group('Drama')
#       Rank                     Title  ...  Revenue  \
# 5979  5980                    Wheels  ...      NaN
# 0        1  The Shawshank Redemption  ...    28.34
# 9161  9162                     Aruvi  ...      NaN
# 9294  9295            Canim Kardesim  ...      NaN
# 4996  4997                     Anand  ...      NaN
# ...    ...                       ...  ...      ...
# 7963  7964                    Cherry  ...     0.00
# 2703  2704                 Showgirls  ...    20.30
# 7674  7675          God's Not Dead 2  ...    20.77
# 8926  8927            Glen or Glenda  ...      NaN
# 2343  2344                  The Room  ...      NaN
#
# ...

# %%
genre_group.get_group('Adventure, Comedy, Sport')
# Out:
# C:\Users\a.gutierrez\AppData\Local\Temp\ipykernel_4244\4192480690.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   genre_group.get_group('Adventure, Comedy, Sport')
#       Rank  Title  ...  Revenue  \
# 7200  7201  Grind  ...     5.11
#
#                                             Description
# 7200  Four skaters follow their idol on his summer t...
#
# [1 rows x 11 columns]

# %%
filtro7 = df['Genre'] == 'Drama'
df.loc[filtro7]
# Out:
#       Rank                     Title  ...  Revenue  \
# 5979  5980                    Wheels  ...      NaN
# 0        1  The Shawshank Redemption  ...    28.34
# 9161  9162                     Aruvi  ...      NaN
# 9294  9295            Canim Kardesim  ...      NaN
# 4996  4997                     Anand  ...      NaN
# ...    ...                       ...  ...      ...
# 7963  7964                    Cherry  ...     0.00
# 2703  2704                 Showgirls  ...    20.30
# 7674  7675          God's Not Dead 2  ...    20.77
# 8926  8927            Glen or Glenda  ...      NaN
# 2343  2344                  The Room  ...      NaN
#
#                                             Description
# 5979  Two suicidal paraplegic junkies hustle their w...
# 0     Two imprisoned men bond over a number of years...
# 9161  A gentle girl born and brought up amidst the e...
# 9294  Two poor men try to find a television as a las...
# 4996  The story of a terminally ill man who wishes t...
# ...

# %%
df.loc[filtro7]['Score'].value_counts()
# Out:
# Score
# 7.4    38
# 7.6    36
# 7.8    35
# 7.3    32
# 7.2    30
# 8.1    28
# 8.0    28
# 7.1    23
# 7.5    21
# 7.9    20
# 7.7    19
# 6.8    19
# 7.0    14
# 6.4    12
# 6.9    12
# 6.5    12
# 8.3    11
# 8.2    11
# 6.6    10
# 6.7     9
# 6.2     9
# 6.3     6
# 5.7     5
# 5.9     5
# 8.4     4
# 6.0     4
# 8.8     3
# 8.5     3
# 5.5     3
# 5.3     3
# 5.6     2
# 6.1     2
# 4.8     2
# 9.4     1
# 9.3     1
# 8.9     1
# 8.7     1
# 5.8     1
# 5.4     1
# 5.0     1
# 4.7     1
# 4.4     1
# 4.2     1
# 3.6     1
# Name: count, dtype: int64

# %%
genre_group['Score'].value_counts().head(15)
# Out:
# Genre              Score
# Action             6.2      2
#                    1.7      1
#                    4.0      1
#                    5.0      1
#                    5.4      1
#                    5.5      1
#                    5.8      1
#                    7.2      1
#                    7.3      1
# Action, Adventure  5.4      2
#                    6.1      2
#                    7.6      2
#                    4.8      1
#                    5.1      1
#                    5.2      1
# Name: count, dtype: int64

# %%
genre_group['Score'].value_counts().loc['Action, Adventure, Comedy']
# Out:
# Score
# 6.7    8
# 6.8    7
# 5.7    6
# 5.8    6
# 6.1    6
# 6.2    6
# 6.6    6
# 7.0    6
# 5.2    5
# 5.5    5
# 6.0    5
# 6.3    5
# 7.3    5
# 5.0    4
# 5.4    4
# 7.1    4
# 3.5    3
# 4.2    3
# 4.4    3
# 5.6    3
# 6.5    3
# 4.8    2
# 4.9    2
# 5.1    2
# 6.4    2
# 6.9    2
# 7.2    2
# 7.7    2
# 8.2    2
# 1.8    1
# 1.9    1
# 2.8    1
# 3.0    1
# 3.7    1
# 3.8    1
# 4.1    1
# 4.3    1
# 4.5    1
# 4.6    1
# 4.7    1
# 5.3    1
# 5.9    1
# 7.6    1
# 7.8    1
# 7.9    1
# 8.0    1
# 8.1    1
# Name: count, dtype: int64

# %%
genre_group['Score'].value_counts(normalize = True).loc['Action, Adventure, Comedy']
# Out:
# Score
# 6.7    0.058394
# 6.8    0.051095
# 5.7    0.043796
# 5.8    0.043796
# 6.1    0.043796
# 6.2    0.043796
# 6.6    0.043796
# 7.0    0.043796
# 5.2    0.036496
# 5.5    0.036496
# 6.0    0.036496
# 6.3    0.036496
# 7.3    0.036496
# 5.0    0.029197
# 5.4    0.029197
# 7.1    0.029197
# 3.5    0.021898
# 4.2    0.021898
# 4.4    0.021898
# 5.6    0.021898
# 6.5    0.021898
# 4.8    0.014599
# 4.9    0.014599
# 5.1    0.014599
# 6.4    0.014599
# 6.9    0.014599
# 7.2    0.014599
# 7.7    0.014599
# 8.2    0.014599
# 1.8    0.007299
# 1.9    0.007299
# 2.8    0.007299
# 3.0    0.007299
# 3.7    0.007299
# 3.8    0.007299
# 4.1    0.007299
# 4.3    0.007299
# 4.5    0.007299
# 4.6    0.007299
# 4.7    0.007299
# 5.3    0.007299
# 5.9    0.007299
# 7.6    0.007299
# 7.8    0.007299
# 7.9    0.007299
# 8.0    0.007299
# 8.1    0.007299
# Name: proportion, dtype: float64

# %%
genre_group['Score'].median()
# Out:
# Genre
# Action                          5.65
# Action, Adventure               6.30
# Action, Adventure, Biography    6.95
# Action, Adventure, Comedy       6.10
# Action, Adventure, Crime        6.00
#                                 ...
# Thriller, Mystery               8.80
# Thriller, War                   6.65
# Thriller, Western               6.90
# War                             7.40
# Western                         7.40
# Name: Score, Length: 486, dtype: float64

# %%
genre_group['Score'].median().loc['War']
# Out:
# np.float64(7.4)

# %%
genre_group['Score'].agg(['mean', 'median'])
# Out:
#                                   mean  median
# Genre
# Action                        5.430000    5.65
# Action, Adventure             6.500000    6.30
# Action, Adventure, Biography  6.950000    6.95
# Action, Adventure, Comedy     5.926277    6.10
# Action, Adventure, Crime      6.042857    6.00
# ...                                ...     ...
# Thriller, Mystery             8.800000    8.80
# Thriller, War                 6.775000    6.65
# Thriller, Western             6.900000    6.90
# War                           7.400000    7.40
# Western                       7.510000    7.40
#
# [486 rows x 2 columns]

# %%
genre_group['Score'].agg(['mean', 'median']).loc['Western']
# Out:
# mean      7.51
# median    7.40
# Name: Western, dtype: float64

# %%
filtro8 = df['Genre'] == 'Western'
df.loc[filtro8]['Title']
# Out:
# 111     The Good, the Bad and the Ugly
# 521       Once Upon a Time in the West
# 779             For a Few Dollars More
# 911               A Fistful of Dollars
# 2623            The Outlaw Josey Wales
# 6985                 The Great Silence
# 8506                    The Gunfighter
# 7346             Ride the High Country
# 6365          She Wore a Yellow Ribbon
# 8460              The Man from Laramie
# 7614                            Hombre
# 3092                        Pale Rider
# 6705           The Sons of Katie Elder
# 7724                          Big Jake
# 8363                    One-Eyed Jacks
# 5782              How the West Was Won
# 9638                      Nevada Smith
# 4073                     Hang 'Em High
# 8735                     The War Wagon
# 6183                          Joe Kidd
# Name: Title, dtype: object
